# %% [markdown]
# #Variables in Python

# %% [markdown]
# * A variable is a name that referes to a value stored in memory
# * You can assign values using the '=' operator.Python is dynamically typed

# %% [markdown]
# **Rules for naming variables**

# %% [markdown]
# 1. Must start with a letter or underscore _
# 2. Cannot start with a number
# 3. Can contain letters,digits,and underscores
# 4. Case sensitive
# 5. Should not use Python Keywords

# %% [markdown]
# #Variable Assignment in Python

# %%
x=10
name="roshan"
is_valid="false"

print(name)
# Out:
# roshan

# %%
print(type(name))
# Out:
# <class 'str'>
